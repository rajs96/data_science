# %% [markdown]
# First we will do a linear classifier to classify whether or not someone has diabetes. We will use the estimator API.

# %%
# tf.estimator.LinearClassifier constructs a linear classification model.
# tf.estimator.LinearRegressor constructs a linear regression model 
# tf.estimator.DNNClassifier constructs a neural network classification model.
# tf.estimator.DNNClassifier constructs a neural network regressor

# %% [markdown]
# In general, to use the Estimator API we do the following:
# - Define a list of feature columns
# - Create the estimator Model
# - Create a Data input function
# - Call train, evaluate, and predict methods on the estimator object

# %%
import pandas as pd
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index([u'Number_pregnant', u'Glucose_concentration', u'Blood_pressure',
#        u'Triceps', u'Insulin', u'BMI', u'Pedigree', u'Age', u'Class',
#        u'Group'],
#       dtype='object')

# %%
# need to normalize/scale columns because data is very spread apart
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure',
       'Triceps', 'Insulin', 'BMI', 'Pedigree']
# scale with pandas .apply function
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x-x.min()) / (x.max() - x.min()))

# %%
import tensorflow as tf
# Out:
# /Users/rajsingh/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# create tensorflow feature columns
# to pass into estimator API
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasm_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %%
# one way of dealing with categorical columns
# must pass in list of possible values
# works better when there are only a few categorical labels
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])

# %%
# let's say there are a lot of categorical possibilities
# we can use hash_bucket
# hash_bucket_size represents the most possibilities we estimate there are
#assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group'hash_bucket_size=10)

# now we will convert a continuous value to a categorical value
# in this case it is age

age_bucket = tf.feature_column.bucketized_column(age,boundaries=[20,30,40,50,60,70,80])

# now create a list of the tf feature columns
feat_cols = [num_preg,plasm_gluc,dias_press,tricep,insulin,diabetes_pedigree,age_bucket]

# %%
# now create the test train split
x_data = diabetes.drop('Class',axis=1)
labels = diabetes['Class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.3,random_state=101)

# %%
# now create an input function
# using an estimator
# using a pandas input function
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=20,num_epochs=1000,shuffle=True)

# %%
# use a linear classifier function
# essentially the same thing as
# multiple linear regression
# note that we must pass in a list of the feature cols
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/g7/8vxnts7s1j7fxnn7zwtb830w0000gn/T/tmp7dyda4
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_global_id_in_cluster': 0, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1a2ba13e90>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_device_fn': None, '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '/var/folders/g7/8vxnts7s1j7fxnn7zwtb830w0000gn/T/tmp7dyda4', '_train_distribute': None, '_save_summary_steps': 100}

# %%
# train the model
model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/g7/8vxnts7s1j7fxnn7zwtb830w0000gn/T/tmp7dyda4/model.ckpt.
# INFO:tensorflow:loss = 13.862944, step = 1
# INFO:tensorflow:global_step/sec: 137.524
# INFO:tensorflow:loss = 11.839209, step = 101 (0.729 sec)
# INFO:tensorflow:global_step/sec: 230.218
# INFO:tensorflow:loss = 9.041603, step = 201 (0.435 sec)
# INFO:tensorflow:global_step/sec: 202.066
# INFO:tensorflow:loss = 8.777344, step = 301 (0.498 sec)
# INFO:tensorflow:global_step/sec: 186.178
# INFO:tensorflow:loss = 8.714936, step = 401 (0.534 sec)
# INFO:tensorflow:global_step/sec: 183.82
# INFO:tensorflow:loss = 10.74392, step = 501 (0.545 sec)
# INFO:tensorflow:global_step/sec: 167.043
# INFO:tensorflow:loss = 9.83637, step = 601 (0.605 sec)
# INFO:tensorflow:global_step/sec: 96.0861
# INFO:tensorflow:loss = 12.556278, step = 701 (1.033 sec)
# INFO:tensorflow:global_step/sec: 186.246
# INFO:tensorflow:loss = 9.460846, step = 801 (0.538 sec)
# INFO:tensorflow:global_step/sec: 181.467
# INFO:tensorflow:loss = 8.792994, step = 901 (0.548 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/g7/8vxnts7s1j7fxnn7zwtb830w0000gn/T/tmp7dyda4/model.ckpt.
# INFO:tensorflow:Loss for final step: 9.107417.

# %%
# pass in evaluation function
eval_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test,y=y_test,batch_size=10,num_epochs=1,
                                                     shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-12-02:29:06
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/g7/8vxnts7s1j7fxnn7zwtb830w0000gn/T/tmp7dyda4/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-12-02:29:07
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.7316017, accuracy_baseline = 0.64935064, auc = 0.80296296, auc_precision_recall = 0.66587216, average_loss = 0.52137256, global_step = 1000, label/mean = 0.35064936, loss = 5.018211, precision = 0.63013697, prediction/mean = 0.37936035, recall = 0.56790125
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /var/folders/g7/8vxnts7s1j7fxnn7zwtb830w0000gn/T/tmp7dyda4/model.ckpt-1000

# %%
results
# Out:
# {'accuracy': 0.7316017,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.80296296,
#  'auc_precision_recall': 0.66587216,
#  'average_loss': 0.52137256,
#  'global_step': 1000,
#  'label/mean': 0.35064936,
#  'loss': 5.018211,
#  'precision': 0.63013697,
#  'prediction/mean': 0.37936035,
#  'recall': 0.56790125}

# %%
# make predictions
# don't pass in a y
pred_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test,
                                                     batch_size=10,
                                                     num_epochs=1,
                                                     shuffle=False)

# %%
predictions = model.predict(pred_input_func)

# %%
my_pred = list(predictions)
my_pred
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/g7/8vxnts7s1j7fxnn7zwtb830w0000gn/T/tmp7dyda4/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.5118053], dtype=float32),
#   'logits': array([0.04723012], dtype=float32),
#   'probabilities': array([0.4881946, 0.5118053], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.69231635], dtype=float32),
#   'logits': array([0.8109708], dtype=float32),
#   'probabilities': array([0.30768368, 0.69231635], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.41585582], dtype=float32),
#   'logits': array([-0.33980918], dtype=float32),
#   'probabilities': array([0.5841442 , 0.41585585], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.30436346], dtype=float32),
#   'logits': array([-0.8266047], dtype=float32),
#   'probabilities': array([0.6956365 , 0.30436346], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.11136357], dtype=float32),
#   'logits': array([-2.0768878], dtype=float32),
#   'probabilities': array([0.8886364 , 0.11136357], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.7358055], dtype=float32),
#   'logits': array([1.0242801], dtype=float32),
#   'probabilities': array([0.26419455, 0.7358055 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.66618776], dtype=float32),
#   'logits': array([0.6909926], dtype=float32),
#   'probabilities': array([0.33381233, 0.66618776], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.2891134], dtype=float32),
#   'logits': array([-0.89969397], dtype=float32),
#   'probabilities': array([0.7108866, 0.2891134], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.23474818], dtype=float32),
#   'logits': array([-1.1816915], dtype=float32),
#   'probabilities': array([0.7652518, 0.2347482], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.21688405], dtype=float32),
#   'logits': array([-1.2839179], dtype=float32),
#   'probabilities': array([0.7831159 , 0.21688405], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.151695], dtype=float32),
#   'logits': array([-1.7213683], dtype=float32),
#   'probabilities': array([0.848305, 0.151695], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.15198646], dtype=float32),
#   'logits': array([-1.7191051], dtype=float32),
#   'probabilities': array([0.8480136 , 0.15198646], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.31019497], dtype=float32),
#   'logits': array([-0.799208], dtype=float32),
#   'probabilities': array([0.68980503, 0.31019497], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.612237], dtype=float32),
#   'logits': array([0.45672512], dtype=float32),
#   'probabilities': array([0.387763, 0.612237], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.17958812], dtype=float32),
#   'logits': array([-1.5191405], dtype=float32),
#   'probabilities': array([0.82041186, 0.17958811], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.4014737], dtype=float32),
#   'logits': array([-0.39932847], dtype=float32),
#   'probabilities': array([0.5985263, 0.4014737], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.4510559], dtype=float32),
#   'logits': array([-0.19640517], dtype=float32),
#   'probabilities': array([0.54894406, 0.45105594], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.12019534], dtype=float32),
#   'logits': array([-1.9905816], dtype=float32),
#   'probabilities': array([0.8798046 , 0.12019534], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.3733632], dtype=float32),
#   'logits': array([-0.51781535], dtype=float32),
#   'probabilities': array([0.6266368 , 0.37336323], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.12844208], dtype=float32),
#   'logits': array([-1.9148042], dtype=float32),
#   'probabilities': array([0.8715579 , 0.12844208], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.2090983], dtype=float32),
#   'logits': array([-1.3303692], dtype=float32),
#   'probabilities': array([0.7909017, 0.2090983], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.29982272], dtype=float32),
#   'logits': array([-0.84814215], dtype=float32),
#   'probabilities': array([0.70017725, 0.29982272], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.6360285], dtype=float32),
#   'logits': array([0.55816793], dtype=float32),
#   'probabilities': array([0.36397147, 0.6360285 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.20573348], dtype=float32),
#   'logits': array([-1.3508376], dtype=float32),
#   'probabilities': array([0.7942665 , 0.20573348], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.1998513], dtype=float32),
#   'logits': array([-1.387224], dtype=float32),
#   'probabilities': array([0.8001487, 0.1998513], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.8348302], dtype=float32),
#   'logits': array([1.6202548], dtype=float32),
#   'probabilities': array([0.16516973, 0.8348302 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.18877213], dtype=float32),
#   'logits': array([-1.4580084], dtype=float32),
#   'probabilities': array([0.81122786, 0.18877213], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.34978575], dtype=float32),
#   'logits': array([-0.61998117], dtype=float32),
#   'probabilities': array([0.65021425, 0.34978572], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.11514533], dtype=float32),
#   'logits': array([-2.0392284], dtype=float32),
#   'probabilities': array([0.8848547 , 0.11514532], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.60507286], dtype=float32),
#   'logits': array([0.42664766], dtype=float32),
#   'probabilities': array([0.39492708, 0.60507286], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.95701456], dtype=float32),
#   'logits': array([3.1029568], dtype=float32),
#   'probabilities': array([0.04298545, 0.95701456], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.3990167], dtype=float32),
#   'logits': array([-0.4095639], dtype=float32),
#   'probabilities': array([0.6009833, 0.3990167], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.32337916], dtype=float32),
#   'logits': array([-0.7382856], dtype=float32),
#   'probabilities': array([0.67662084, 0.32337913], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.5208764], dtype=float32),
#   'logits': array([0.08355415], dtype=float32),
#   'probabilities': array([0.47912362, 0.5208764 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.28115362], dtype=float32),
#   'logits': array([-0.93874645], dtype=float32),
#   'probabilities': array([0.7188464 , 0.28115362], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.40127158], dtype=float32),
#   'logits': array([-0.40016973], dtype=float32),
#   'probabilities': array([0.5987284 , 0.40127155], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.53229415], dtype=float32),
#   'logits': array([0.12935674], dtype=float32),
#   'probabilities': array([0.46770582, 0.53229415], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.6535226], dtype=float32),
#   'logits': array([0.63455963], dtype=float32),
#   'probabilities': array([0.34647736, 0.6535226 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.80429757], dtype=float32),
#   'logits': array([1.413374], dtype=float32),
#   'probabilities': array([0.19570245, 0.80429757], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.2939131], dtype=float32),
#   'logits': array([-0.87645423], dtype=float32),
#   'probabilities': array([0.70608693, 0.2939131 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.17561816], dtype=float32),
#   'logits': array([-1.5463217], dtype=float32),
#   'probabilities': array([0.8243818 , 0.17561816], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.5681502], dtype=float32),
#   'logits': array([0.2743081], dtype=float32),
#   'probabilities': array([0.43184978, 0.5681502 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.18289223], dtype=float32),
#   'logits': array([-1.496874], dtype=float32),
#   'probabilities': array([0.81710774, 0.18289222], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.60108167], dtype=float32),
#   'logits': array([0.4099741], dtype=float32),
#   'probabilities': array([0.39891833, 0.60108167], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.14963259], dtype=float32),
#   'logits': array([-1.7374856], dtype=float32),
#   'probabilities': array([0.8503675 , 0.14963259], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.13981967], dtype=float32),
#   'logits': array([-1.8167887], dtype=float32),
#   'probabilities': array([0.8601804 , 0.13981965], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.53755635], dtype=float32),
#   'logits': array([0.15050888], dtype=float32),
#   'probabilities': array([0.46244365, 0.53755635], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.14025982], dtype=float32),
#   'logits': array([-1.8131337], dtype=float32),
#   'probabilities': array([0.8597402 , 0.14025982], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.22261915], dtype=float32),
#   'logits': array([-1.250468], dtype=float32),
#   'probabilities': array([0.7773809 , 0.22261915], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.18677348], dtype=float32),
#   'logits': array([-1.4711132], dtype=float32),
#   'probabilities': array([0.8132265 , 0.18677346], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.17284538], dtype=float32),
#   'logits': array([-1.5655942], dtype=float32),
#   'probabilities': array([0.8271546 , 0.17284538], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.29630756], dtype=float32),
#   'logits': array([-0.8649433], dtype=float32),
#   'probabilities': array([0.70369244, 0.29630756], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.25158498], dtype=float32),
#   'logits': array([-1.0901768], dtype=float32),
#   'probabilities': array([0.748415  , 0.25158498], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.34778643], dtype=float32),
#   'logits': array([-0.62878346], dtype=float32),
#   'probabilities': array([0.6522136 , 0.34778646], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.11819569], dtype=float32),
#   'logits': array([-2.0096285], dtype=float32),
#   'probabilities': array([0.88180435, 0.11819568], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.24130732], dtype=float32),
#   'logits': array([-1.1455255], dtype=float32),
#   'probabilities': array([0.7586926 , 0.24130732], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.19608688], dtype=float32),
#   'logits': array([-1.4109334], dtype=float32),
#   'probabilities': array([0.8039131 , 0.19608688], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.22124864], dtype=float32),
#   'logits': array([-1.2584046], dtype=float32),
#   'probabilities': array([0.7787513 , 0.22124863], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.5096885], dtype=float32),
#   'logits': array([0.03875875], dtype=float32),
#   'probabilities': array([0.49031153, 0.5096885 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.12795362], dtype=float32),
#   'logits': array([-1.9191747], dtype=float32),
#   'probabilities': array([0.87204635, 0.12795362], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.21592486], dtype=float32),
#   'logits': array([-1.2895745], dtype=float32),
#   'probabilities': array([0.78407514, 0.21592484], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.706801], dtype=float32),
#   'logits': array([0.8798976], dtype=float32),
#   'probabilities': array([0.293199, 0.706801], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.6634623], dtype=float32),
#   'logits': array([0.6787617], dtype=float32),
#   'probabilities': array([0.33653772, 0.6634623 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.5127397], dtype=float32),
#   'logits': array([0.05096984], dtype=float32),
#   'probabilities': array([0.4872603, 0.5127397], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.3474632], dtype=float32),
#   'logits': array([-0.63020885], dtype=float32),
#   'probabilities': array([0.6525368, 0.3474632], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.5181216], dtype=float32),
#   'logits': array([0.07251823], dtype=float32),
#   'probabilities': array([0.48187837, 0.5181216 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.19115376], dtype=float32),
#   'logits': array([-1.4425306], dtype=float32),
#   'probabilities': array([0.80884624, 0.19115378], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.18129632], dtype=float32),
#   'logits': array([-1.5075895], dtype=float32),
#   'probabilities': array([0.81870365, 0.1812963 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.15093446], dtype=float32),
#   'logits': array([-1.7272907], dtype=float32),
#   'probabilities': array([0.84906554, 0.15093444], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.11780948], dtype=float32),
#   'logits': array([-2.0133393], dtype=float32),
#   'probabilities': array([0.88219047, 0.11780948], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.6867678], dtype=float32),
#   'logits': array([0.7850516], dtype=float32),
#   'probabilities': array([0.31323218, 0.6867678 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.27465728], dtype=float32),
#   'logits': array([-0.9711202], dtype=float32),
#   'probabilities': array([0.7253427 , 0.27465728], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.43113592], dtype=float32),
#   'logits': array([-0.27721822], dtype=float32),
#   'probabilities': array([0.5688641, 0.4311359], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.6183108], dtype=float32),
#   'logits': array([0.48238456], dtype=float32),
#   'probabilities': array([0.38168922, 0.6183108 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.29506975], dtype=float32),
#   'logits': array([-0.87088716], dtype=float32),
#   'probabilities': array([0.70493025, 0.29506975], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.66379863], dtype=float32),
#   'logits': array([0.68026876], dtype=float32),
#   'probabilities': array([0.3362013 , 0.66379863], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.11031587], dtype=float32),
#   'logits': array([-2.0875187], dtype=float32),
#   'probabilities': array([0.8896841 , 0.11031587], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.68866825], dtype=float32),
#   'logits': array([0.7939005], dtype=float32),
#   'probabilities': array([0.31133178, 0.68866825], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.12410228], dtype=float32),
#   'logits': array([-1.9541433], dtype=float32),
#   'probabilities': array([0.8758977 , 0.12410228], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.60451144], dtype=float32),
#   'logits': array([0.42429864], dtype=float32),
#   'probabilities': array([0.3954886 , 0.60451144], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.39562717], dtype=float32),
#   'logits': array([-0.42371905], dtype=float32),
#   'probabilities': array([0.60437286, 0.39562717], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.18526499], dtype=float32),
#   'logits': array([-1.4810758], dtype=float32),
#   'probabilities': array([0.81473505, 0.185265  ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.5691821], dtype=float32),
#   'logits': array([0.27851486], dtype=float32),
#   'probabilities': array([0.4308179, 0.5691821], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.59101504], dtype=float32),
#   'logits': array([0.3681631], dtype=float32),
#   'probabilities': array([0.40898496, 0.59101504], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.6391458], dtype=float32),
#   'logits': array([0.5716584], dtype=float32),
#   'probabilities': array([0.36085427, 0.6391458 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.1759912], dtype=float32),
#   'logits': array([-1.5437472], dtype=float32),
#   'probabilities': array([0.82400876, 0.1759912 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.5052017], dtype=float32),
#   'logits': array([0.0208075], dtype=float32),
#   'probabilities': array([0.49479833, 0.5052017 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.16960587], dtype=float32),
#   'logits': array([-1.5884231], dtype=float32),
#   'probabilities': array([0.8303941 , 0.16960585], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.7585632], dtype=float32),
#   'logits': array([1.1448188], dtype=float32),
#   'probabilities': array([0.2414367, 0.7585632], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.8459257], dtype=float32),
#   'logits': array([1.7029965], dtype=float32),
#   'probabilities': array([0.15407431, 0.8459257 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.6402672], dtype=float32),
#   'logits': array([0.576524], dtype=float32),
#   'probabilities': array([0.3597328, 0.6402672], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.19654249], dtype=float32),
#   'logits': array([-1.4080456], dtype=float32),
#   'probabilities': array([0.8034575 , 0.19654249], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.49849322], dtype=float32),
#   'logits': array([-0.00602722], dtype=float32),
#   'probabilities': array([0.5015068, 0.4984932], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.38874447], dtype=float32),
#   'logits': array([-0.45259285], dtype=float32),
#   'probabilities': array([0.6112555 , 0.38874447], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.43025687], dtype=float32),
#   'logits': array([-0.28080332], dtype=float32),
#   'probabilities': array([0.56974316, 0.43025684], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.38622993], dtype=float32),
#   'logits': array([-0.46318758], dtype=float32),
#   'probabilities': array([0.61377007, 0.38622993], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.4140489], dtype=float32),
#   'logits': array([-0.34725213], dtype=float32),
#   'probabilities': array([0.5859511 , 0.41404894], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.1834786], dtype=float32),
#   'logits': array([-1.4929552], dtype=float32),
#   'probabilities': array([0.8165214 , 0.18347858], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.6074974], dtype=float32),
#   'logits': array([0.43680477], dtype=float32),
#   'probabilities': array([0.39250258, 0.6074974 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.562068], dtype=float32),
#   'logits': array([0.24955904], dtype=float32),
#   'probabilities': array([0.43793207, 0.562068  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.28463542], dtype=float32),
#   'logits': array([-0.92158324], dtype=float32),
#   'probabilities': array([0.7153646 , 0.28463542], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.19999458], dtype=float32),
#   'logits': array([-1.3863282], dtype=float32),
#   'probabilities': array([0.80000544, 0.1999946 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.16185732], dtype=float32),
#   'logits': array([-1.6444731], dtype=float32),
#   'probabilities': array([0.8381427 , 0.16185734], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.23731783], dtype=float32),
#   'logits': array([-1.1674411], dtype=float32),
#   'probabilities': array([0.7626822 , 0.23731783], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.40066463], dtype=float32),
#   'logits': array([-0.4026966], dtype=float32),
#   'probabilities': array([0.5993354 , 0.40066463], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.14401805], dtype=float32),
#   'logits': array([-1.7823106], dtype=float32),
#   'probabilities': array([0.855982  , 0.14401807], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.30811253], dtype=float32),
#   'logits': array([-0.8089583], dtype=float32),
#   'probabilities': array([0.6918875 , 0.30811253], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.24011093], dtype=float32),
#   'logits': array([-1.1520714], dtype=float32),
#   'probabilities': array([0.759889  , 0.24011092], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.10898281], dtype=float32),
#   'logits': array([-2.1011736], dtype=float32),
#   'probabilities': array([0.8910172, 0.1089828], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.13136253], dtype=float32),
#   'logits': array([-1.8889649], dtype=float32),
#   'probabilities': array([0.86863744, 0.13136253], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.7254091], dtype=float32),
#   'logits': array([0.9714532], dtype=float32),
#   'probabilities': array([0.27459097, 0.7254091 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.17029877], dtype=float32),
#   'logits': array([-1.5835114], dtype=float32),
#   'probabilities': array([0.82970124, 0.17029877], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.14300783], dtype=float32),
#   'logits': array([-1.7905294], dtype=float32),
#   'probabilities': array([0.8569922 , 0.14300784], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.1718077], dtype=float32),
#   'logits': array([-1.5728695], dtype=float32),
#   'probabilities': array([0.8281923, 0.1718077], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.51602936], dtype=float32),
#   'logits': array([0.06413949], dtype=float32),
#   'probabilities': array([0.4839706 , 0.51602936], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.47918713], dtype=float32),
#   'logits': array([-0.08329952], dtype=float32),
#   'probabilities': array([0.52081287, 0.4791872 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.24099107], dtype=float32),
#   'logits': array([-1.1472536], dtype=float32),
#   'probabilities': array([0.75900894, 0.24099109], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.44443136], dtype=float32),
#   'logits': array([-0.2231965], dtype=float32),
#   'probabilities': array([0.55556864, 0.44443136], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.19419539], dtype=float32),
#   'logits': array([-1.4229765], dtype=float32),
#   'probabilities': array([0.8058046 , 0.19419539], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.22678101], dtype=float32),
#   'logits': array([-1.2265775], dtype=float32),
#   'probabilities': array([0.773219  , 0.22678101], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.58602285], dtype=float32),
#   'logits': array([0.347548], dtype=float32),
#   'probabilities': array([0.41397715, 0.58602285], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.5463432], dtype=float32),
#   'logits': array([0.18590629], dtype=float32),
#   'probabilities': array([0.45365685, 0.5463432 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.15386572], dtype=float32),
#   'logits': array([-1.7045977], dtype=float32),
#   'probabilities': array([0.84613425, 0.15386572], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.35828286], dtype=float32),
#   'logits': array([-0.58282477], dtype=float32),
#   'probabilities': array([0.6417171 , 0.35828286], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.6702388], dtype=float32),
#   'logits': array([0.70926523], dtype=float32),
#   'probabilities': array([0.32976124, 0.6702388 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.57151717], dtype=float32),
#   'logits': array([0.28804374], dtype=float32),
#   'probabilities': array([0.4284829 , 0.57151717], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.42462346], dtype=float32),
#   'logits': array([-0.3038218], dtype=float32),
#   'probabilities': array([0.5753766 , 0.42462352], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.6191311], dtype=float32),
#   'logits': array([0.48586154], dtype=float32),
#   'probabilities': array([0.380869 , 0.6191311], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.2291806], dtype=float32),
#   'logits': array([-1.2129437], dtype=float32),
#   'probabilities': array([0.77081937, 0.22918062], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.1936446], dtype=float32),
#   'logits': array([-1.4265001], dtype=float32),
#   'probabilities': array([0.8063554, 0.1936446], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.14874437], dtype=float32),
#   'logits': array([-1.7444832], dtype=float32),
#   'probabilities': array([0.8512556 , 0.14874437], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.3334898], dtype=float32),
#   'logits': array([-0.69244313], dtype=float32),
#   'probabilities': array([0.6665102, 0.3334898], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.55025744], dtype=float32),
#   'logits': array([0.20171094], dtype=float32),
#   'probabilities': array([0.44974256, 0.55025744], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.7306255], dtype=float32),
#   'logits': array([0.99779844], dtype=float32),
#   'probabilities': array([0.2693745, 0.7306255], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.22601266], dtype=float32),
#   'logits': array([-1.2309645], dtype=float32),
#   'probabilities': array([0.77398735, 0.22601265], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.19287026], dtype=float32),
#   'logits': array([-1.4314667], dtype=float32),
#   'probabilities': array([0.8071298 , 0.19287027], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.37591466], dtype=float32),
#   'logits': array([-0.50692487], dtype=float32),
#   'probabilities': array([0.6240853, 0.3759147], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.23423526], dtype=float32),
#   'logits': array([-1.1845491], dtype=float32),
#   'probabilities': array([0.7657647 , 0.23423523], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.15254316], dtype=float32),
#   'logits': array([-1.7147924], dtype=float32),
#   'probabilities': array([0.8474568 , 0.15254316], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.17852932], dtype=float32),
#   'logits': array([-1.5263433], dtype=float32),
#   'probabilities': array([0.8214707 , 0.17852932], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.14775585], dtype=float32),
#   'logits': array([-1.7523118], dtype=float32),
#   'probabilities': array([0.8522442 , 0.14775585], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.40588763], dtype=float32),
#   'logits': array([-0.38099217], dtype=float32),
#   'probabilities': array([0.5941124 , 0.40588763], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.7806083], dtype=float32),
#   'logits': array([1.2692149], dtype=float32),
#   'probabilities': array([0.21939167, 0.7806083 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.8075282], dtype=float32),
#   'logits': array([1.4340284], dtype=float32),
#   'probabilities': array([0.19247179, 0.8075282 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.5751543], dtype=float32),
#   'logits': array([0.30291224], dtype=float32),
#   'probabilities': array([0.42484573, 0.5751543 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.54790986], dtype=float32),
#   'logits': array([0.19222903], dtype=float32),
#   'probabilities': array([0.45209023, 0.54790986], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.67719525], dtype=float32),
#   'logits': array([0.74091196], dtype=float32),
#   'probabilities': array([0.32280475, 0.67719525], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.12710719], dtype=float32),
#   'logits': array([-1.926782], dtype=float32),
#   'probabilities': array([0.8728928 , 0.12710719], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.58777404], dtype=float32),
#   'logits': array([0.35477114], dtype=float32),
#   'probabilities': array([0.41222587, 0.58777404], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.75409764], dtype=float32),
#   'logits': array([1.1205876], dtype=float32),
#   'probabilities': array([0.24590228, 0.75409764], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.42762005], dtype=float32),
#   'logits': array([-0.29156792], dtype=float32),
#   'probabilities': array([0.57237995, 0.42762008], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.29992798], dtype=float32),
#   'logits': array([-0.84764093], dtype=float32),
#   'probabilities': array([0.70007205, 0.29992795], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.3142071], dtype=float32),
#   'logits': array([-0.78052324], dtype=float32),
#   'probabilities': array([0.68579286, 0.3142071 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.5490779], dtype=float32),
#   'logits': array([0.19694567], dtype=float32),
#   'probabilities': array([0.45092213, 0.5490779 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.2208937], dtype=float32),
#   'logits': array([-1.260466], dtype=float32),
#   'probabilities': array([0.7791063, 0.2208937], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.6900179], dtype=float32),
#   'logits': array([0.80020285], dtype=float32),
#   'probabilities': array([0.30998212, 0.6900179 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.42765567], dtype=float32),
#   'logits': array([-0.2914225], dtype=float32),
#   'probabilities': array([0.57234436, 0.42765564], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.4576002], dtype=float32),
#   'logits': array([-0.17000747], dtype=float32),
#   'probabilities': array([0.5423998 , 0.45760024], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.17423834], dtype=float32),
#   'logits': array([-1.5558821], dtype=float32),
#   'probabilities': array([0.8257617 , 0.17423832], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.21809459], dtype=float32),
#   'logits': array([-1.2768049], dtype=float32),
#   'probabilities': array([0.7819054 , 0.21809457], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.19662975], dtype=float32),
#   'logits': array([-1.4074932], dtype=float32),
#   'probabilities': array([0.80337024, 0.19662973], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.45762134], dtype=float32),
#   'logits': array([-0.16992235], dtype=float32),
#   'probabilities': array([0.54237866, 0.45762134], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.16863742], dtype=float32),
#   'logits': array([-1.595315], dtype=float32),
#   'probabilities': array([0.83136255, 0.16863742], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.7623435], dtype=float32),
#   'logits': array([1.1655712], dtype=float32),
#   'probabilities': array([0.23765643, 0.7623435 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.18779996], dtype=float32),
#   'logits': array([-1.4643693], dtype=float32),
#   'probabilities': array([0.8122    , 0.18779996], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.47204623], dtype=float32),
#   'logits': array([-0.1119318], dtype=float32),
#   'probabilities': array([0.5279538 , 0.47204626], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.15970063], dtype=float32),
#   'logits': array([-1.6604571], dtype=float32),
#   'probabilities': array([0.84029937, 0.15970065], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.70698756], dtype=float32),
#   'logits': array([0.8807981], dtype=float32),
#   'probabilities': array([0.2930124 , 0.70698756], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.29837823], dtype=float32),
#   'logits': array([-0.85503256], dtype=float32),
#   'probabilities': array([0.7016218 , 0.29837823], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.15113693], dtype=float32),
#   'logits': array([-1.7257116], dtype=float32),
#   'probabilities': array([0.84886307, 0.15113693], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.3412051], dtype=float32),
#   'logits': array([-0.6579284], dtype=float32),
#   'probabilities': array([0.6587949 , 0.34120515], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.37085855], dtype=float32),
#   'logits': array([-0.52853537], dtype=float32),
#   'probabilities': array([0.6291414 , 0.37085852], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.14920145], dtype=float32),
#   'logits': array([-1.740878], dtype=float32),
#   'probabilities': array([0.85079855, 0.14920145], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.70436925], dtype=float32),
#   'logits': array([0.8681915], dtype=float32),
#   'probabilities': array([0.29563075, 0.70436925], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.20264684], dtype=float32),
#   'logits': array([-1.369833], dtype=float32),
#   'probabilities': array([0.79735315, 0.20264684], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.16765082], dtype=float32),
#   'logits': array([-1.6023687], dtype=float32),
#   'probabilities': array([0.8323492 , 0.16765082], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.2653325], dtype=float32),
#   'logits': array([-1.0184343], dtype=float32),
#   'probabilities': array([0.7346675, 0.2653325], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.424341], dtype=float32),
#   'logits': array([-0.30497813], dtype=float32),
#   'probabilities': array([0.57565904, 0.424341  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.26063386], dtype=float32),
#   'logits': array([-1.0426767], dtype=float32),
#   'probabilities': array([0.7393662 , 0.26063386], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.11323788], dtype=float32),
#   'logits': array([-2.058086], dtype=float32),
#   'probabilities': array([0.8867621, 0.1132379], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.84385085], dtype=float32),
#   'logits': array([1.6871638], dtype=float32),
#   'probabilities': array([0.15614921, 0.84385085], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.71807706], dtype=float32),
#   'logits': array([0.9349432], dtype=float32),
#   'probabilities': array([0.2819229 , 0.71807706], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.57424444], dtype=float32),
#   'logits': array([0.2991898], dtype=float32),
#   'probabilities': array([0.42575553, 0.57424444], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.7588837], dtype=float32),
#   'logits': array([1.1465693], dtype=float32),
#   'probabilities': array([0.24111629, 0.7588837 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.17741634], dtype=float32),
#   'logits': array([-1.533951], dtype=float32),
#   'probabilities': array([0.8225837 , 0.17741634], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.128837], dtype=float32),
#   'logits': array([-1.9112811], dtype=float32),
#   'probabilities': array([0.871163, 0.128837], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.2130291], dtype=float32),
#   'logits': array([-1.3067625], dtype=float32),
#   'probabilities': array([0.7869709 , 0.21302912], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.33679634], dtype=float32),
#   'logits': array([-0.6776038], dtype=float32),
#   'probabilities': array([0.66320366, 0.3367963 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.36721337], dtype=float32),
#   'logits': array([-0.5441903], dtype=float32),
#   'probabilities': array([0.63278663, 0.36721334], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.5503755], dtype=float32),
#   'logits': array([0.20218801], dtype=float32),
#   'probabilities': array([0.4496245, 0.5503755], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.6292506], dtype=float32),
#   'logits': array([0.52900314], dtype=float32),
#   'probabilities': array([0.37074944, 0.6292506 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.38605896], dtype=float32),
#   'logits': array([-0.4639088], dtype=float32),
#   'probabilities': array([0.613941  , 0.38605893], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.38500792], dtype=float32),
#   'logits': array([-0.46834552], dtype=float32),
#   'probabilities': array([0.6149921 , 0.38500792], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.29104957], dtype=float32),
#   'logits': array([-0.890292], dtype=float32),
#   'probabilities': array([0.70895046, 0.2910496 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.15770258], dtype=float32),
#   'logits': array([-1.6754223], dtype=float32),
#   'probabilities': array([0.8422974 , 0.15770258], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.58202595], dtype=float32),
#   'logits': array([0.33109546], dtype=float32),
#   'probabilities': array([0.41797414, 0.58202595], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.14352578], dtype=float32),
#   'logits': array([-1.7863096], dtype=float32),
#   'probabilities': array([0.8564742 , 0.14352578], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.24171475], dtype=float32),
#   'logits': array([-1.1433014], dtype=float32),
#   'probabilities': array([0.7582853 , 0.24171475], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.5673319], dtype=float32),
#   'logits': array([0.27097368], dtype=float32),
#   'probabilities': array([0.43266806, 0.5673319 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.4090547], dtype=float32),
#   'logits': array([-0.36787462], dtype=float32),
#   'probabilities': array([0.5909453 , 0.40905467], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.18378866], dtype=float32),
#   'logits': array([-1.4908869], dtype=float32),
#   'probabilities': array([0.81621134, 0.18378863], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.3330257], dtype=float32),
#   'logits': array([-0.69453186], dtype=float32),
#   'probabilities': array([0.6669743, 0.3330257], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.24142008], dtype=float32),
#   'logits': array([-1.1449097], dtype=float32),
#   'probabilities': array([0.7585799 , 0.24142008], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.12813802], dtype=float32),
#   'logits': array([-1.9175231], dtype=float32),
#   'probabilities': array([0.871862  , 0.12813804], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.23751467], dtype=float32),
#   'logits': array([-1.166354], dtype=float32),
#   'probabilities': array([0.7624854 , 0.23751466], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.5565373], dtype=float32),
#   'logits': array([0.22712028], dtype=float32),
#   'probabilities': array([0.44346276, 0.5565373 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.6826602], dtype=float32),
#   'logits': array([0.76602435], dtype=float32),
#   'probabilities': array([0.31733975, 0.6826602 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.70057106], dtype=float32),
#   'logits': array([0.85001874], dtype=float32),
#   'probabilities': array([0.2994289 , 0.70057106], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.71255296], dtype=float32),
#   'logits': array([0.90781546], dtype=float32),
#   'probabilities': array([0.28744707, 0.71255296], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.4663489], dtype=float32),
#   'logits': array([-0.1348083], dtype=float32),
#   'probabilities': array([0.5336511 , 0.46634886], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.2889425], dtype=float32),
#   'logits': array([-0.9005257], dtype=float32),
#   'probabilities': array([0.71105754, 0.2889425 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.49416605], dtype=float32),
#   'logits': array([-0.02333689], dtype=float32),
#   'probabilities': array([0.505834  , 0.49416608], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.2012167], dtype=float32),
#   'logits': array([-1.3787073], dtype=float32),
#   'probabilities': array([0.7987833, 0.2012167], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.1826934], dtype=float32),
#   'logits': array([-1.498205], dtype=float32),
#   'probabilities': array([0.81730664, 0.1826934 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.19146156], dtype=float32),
#   'logits': array([-1.4405411], dtype=float32),
#   'probabilities': array([0.80853844, 0.19146156], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.47355536], dtype=float32),
#   'logits': array([-0.1058774], dtype=float32),
#   'probabilities': array([0.5264447, 0.4735554], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.04274243], dtype=float32),
#   'logits': array([-3.1088805], dtype=float32),
#   'probabilities': array([0.95725757, 0.04274242], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.29855517], dtype=float32),
#   'logits': array([-0.8541875], dtype=float32),
#   'probabilities': array([0.7014448 , 0.29855517], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.17029549], dtype=float32),
#   'logits': array([-1.5835345], dtype=float32),
#   'probabilities': array([0.8297045, 0.1702955], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.22299476], dtype=float32),
#   'logits': array([-1.2482989], dtype=float32),
#   'probabilities': array([0.77700526, 0.22299474], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.2608022], dtype=float32),
#   'logits': array([-1.0418032], dtype=float32),
#   'probabilities': array([0.7391978, 0.2608022], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.2869966], dtype=float32),
#   'logits': array([-0.91001576], dtype=float32),
#   'probabilities': array([0.7130034 , 0.28699663], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.8054781], dtype=float32),
#   'logits': array([1.420891], dtype=float32),
#   'probabilities': array([0.19452195, 0.8054781 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.21123499], dtype=float32),
#   'logits': array([-1.3174973], dtype=float32),
#   'probabilities': array([0.788765  , 0.21123499], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.13363253], dtype=float32),
#   'logits': array([-1.8692155], dtype=float32),
#   'probabilities': array([0.86636746, 0.13363251], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.6469809], dtype=float32),
#   'logits': array([0.60579467], dtype=float32),
#   'probabilities': array([0.35301906, 0.6469809 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.4876357], dtype=float32),
#   'logits': array([-0.04946709], dtype=float32),
#   'probabilities': array([0.51236427, 0.4876358 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.87120986], dtype=float32),
#   'logits': array([1.9116983], dtype=float32),
#   'probabilities': array([0.12879018, 0.87120986], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.6243582], dtype=float32),
#   'logits': array([0.508088], dtype=float32),
#   'probabilities': array([0.37564185, 0.6243582 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array(['0'], dtype=object),
#   'logistic': array([0.15129809], dtype=float32),
#   'logits': array([-1.724456], dtype=float32),
#   'probabilities': array([0.8487019 , 0.15129809], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array(['1'], dtype=object),
#   'logistic': array([0.6224417], dtype=float32),
#   'logits': array([0.49992514], dtype=float32),
#   'probabilities': array([0.37755826, 0.6224417 ], dtype=float32)}]

# %%
# now do a deep neural network
# hidden_units provides a list with how many neurons are
# in the layer
# hidden_units = [10,10,10] means that we have three 10-neuron layers
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],
                                      feature_columns=feat_cols,
                                      n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/g7/8vxnts7s1j7fxnn7zwtb830w0000gn/T/tmpW9EMEV
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_global_id_in_cluster': 0, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1a2dd5f290>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_device_fn': None, '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '/var/folders/g7/8vxnts7s1j7fxnn7zwtb830w0000gn/T/tmpW9EMEV', '_train_distribute': None, '_save_summary_steps': 100}

# %%
# need to embed categorical columns, specifically group column
embedding_group_col = tf.feature_column.embedding_column(assigned_group,
                                                        dimension=4)

# %%
# redefine feat_cols
feat_cols = [num_preg,plasm_gluc,dias_press,tricep,insulin,
             diabetes_pedigree,embedding_group_col,age_bucket]

# %%
# must create our input function
input_func = tf.estimator.inputs.pandas_input_fn(X_train,y_train,
                                                batch_size=10,
                                                num_epochs=1000,
                                                shuffle=True)

# %%
# note that default activation function is 'relu'
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],
                                      feature_columns=feat_cols,
                                      n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/g7/8vxnts7s1j7fxnn7zwtb830w0000gn/T/tmprcKUDx
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_global_id_in_cluster': 0, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1a2deecf50>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_device_fn': None, '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '/var/folders/g7/8vxnts7s1j7fxnn7zwtb830w0000gn/T/tmprcKUDx', '_train_distribute': None, '_save_summary_steps': 100}

# %%
# train DNN model first
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/g7/8vxnts7s1j7fxnn7zwtb830w0000gn/T/tmprcKUDx/model.ckpt.
# INFO:tensorflow:loss = 7.307909, step = 1
# INFO:tensorflow:global_step/sec: 172.782
# INFO:tensorflow:loss = 5.037978, step = 101 (0.585 sec)
# INFO:tensorflow:global_step/sec: 224.038
# INFO:tensorflow:loss = 4.754703, step = 201 (0.446 sec)
# INFO:tensorflow:global_step/sec: 178.176
# INFO:tensorflow:loss = 7.062928, step = 301 (0.559 sec)
# INFO:tensorflow:global_step/sec: 174.673
# INFO:tensorflow:loss = 4.528586, step = 401 (0.582 sec)
# INFO:tensorflow:global_step/sec: 165.524
# INFO:tensorflow:loss = 6.1241517, step = 501 (0.594 sec)
# INFO:tensorflow:global_step/sec: 180.679
# INFO:tensorflow:loss = 4.473522, step = 601 (0.560 sec)
# INFO:tensorflow:global_step/sec: 170.255
# INFO:tensorflow:loss = 3.1622434, step = 701 (0.583 sec)
# INFO:tensorflow:global_step/sec: 156.029
# INFO:tensorflow:loss = 3.6797252, step = 801 (0.643 sec)
# INFO:tensorflow:global_step/sec: 170.923
# INFO:tensorflow:loss = 6.132429, step = 901 (0.583 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/g7/8vxnts7s1j7fxnn7zwtb830w0000gn/T/tmprcKUDx/model.ckpt.
# INFO:tensorflow:Loss for final step: 8.090834.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test,y=y_test,
                                                     batch_size=10,
                                                     num_epochs=1,
                                                     shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-12-03:00:05
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/g7/8vxnts7s1j7fxnn7zwtb830w0000gn/T/tmprcKUDx/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-12-03:00:06
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.74891776, accuracy_baseline = 0.64935064, auc = 0.8271605, auc_precision_recall = 0.69825613, average_loss = 0.48577192, global_step = 1000, label/mean = 0.35064936, loss = 4.6755548, precision = 0.6666667, prediction/mean = 0.3344637, recall = 0.56790125
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /var/folders/g7/8vxnts7s1j7fxnn7zwtb830w0000gn/T/tmprcKUDx/model.ckpt-1000
# {'accuracy': 0.74891776,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.8271605,
#  'auc_precision_recall': 0.69825613,
#  'average_loss': 0.48577192,
#  'global_step': 1000,
#  'label/mean': 0.35064936,
#  'loss': 4.6755548,
#  'precision': 0.6666667,
#  'prediction/mean': 0.3344637,
#  'recall': 0.56790125}
